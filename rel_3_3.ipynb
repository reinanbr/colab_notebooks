# %% [markdown]
# <a href="https://colab.research.google.com/github/reinanbr/colab_notebooks/blob/main/rel_3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dados organizados e corrigidos (trocando ',' por '.')
time = np.array([0, 30, 60, 90, 120, 150, 180, 210, 240, 270,
                 300, 330, 360, 390, 420, 450, 480, 510, 570, 600])

resistor = np.array([10, 8.13, 7.35, 6.76, 6.16, 5.69, 5.27, 4.89, 4.55, 4.30,
                     4.02, 3.75, 3.54, 3.28, 3.02, 2.91, 2.76, 2.62, 2.32, 2.24])

capacitor = np.array([0, 1.9, 2.61, 3.25, 3.84, 4.33, 4.7, 5.10, 5.44, 5.71,
                      6.01, 6.23, 6.23, 6.47, 6.70, 7.08, 7.22, 7.35, 7.67, 7.75])

# Criar a figura e os dois eixos Y
fig, ax1 = plt.subplots(figsize=(5, 6), facecolor='black')
ax1.set_facecolor('black')

# Eixo Y esquerdo - Resistor
ax1.plot(time, resistor, 'o', color='cyan', label='Tensão no Resistor (V)')
ax1.set_xlabel('Tempo (s)', color='white')
ax1.set_ylabel('Tensão no Resistor (V)', color='cyan')
ax1.tick_params(axis='y', labelcolor='cyan')
ax1.tick_params(axis='x', colors='white')

# Eixo Y direito - Capacitor
ax2 = ax1.twinx()
ax2.plot(time, capacitor, 's', color='lime', label='Tensão no Capacitor (V)')
ax2.set_ylabel('Tensão no Capacitor (V)', color='lime')
ax2.tick_params(axis='y', labelcolor='lime')

# Título e grid
plt.title("Carregamento de um Capacitor em Circuito RC", color='white')
ax1.grid(True, linestyle='--', alpha=0.3)

# Legenda combinada
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
plt.legend(lines1 + lines2, labels1 + labels2, loc='center right')

# Exibe o gráfico
plt.tight_layout()
plt.show()

# %%
diff = np.abs(resistor - capacitor)

# Criar a figura e os dois eixos Y
fig, ax1 = plt.subplots(figsize=(5, 6), facecolor='black')
ax1.set_facecolor('black')

ax1.set_xlabel('Tempo (s)', color='white')
ax1.set_ylabel('Tensão no Resistor (V)', color='violet')
ax1.tick_params(axis='y', labelcolor='violet')
ax1.tick_params(axis='x', colors='white')


plt.plot(time,diff,'o',color='violet')

plt.title("Discrepância entre as tensões", color='white')
ax1.grid(True, linestyle='--', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parâmetros
R = 147.9e3  # resistência em ohms
C = 1.25e-3  # capacitância em farads
E = 8        # tensão da fonte (em volts)
RC = R * C   # constante de tempo (s)

# Vetor de tempo
t = np.linspace(0, 5 * RC, 500)

# Equações teóricas
Vc = E * (1 - np.exp(-t / RC))        # tensão no capacitor
Q = C * Vc                            # carga no capacitor
Q_micro = Q * 1e6                     # carga em microcoulombs (μC)
print(Q_micro)
# Criar a figura e dois eixos Y
fig, ax1 = plt.subplots(figsize=(5, 6), facecolor='black')
ax1.set_facecolor('black')

# Eixo da esquerda: tensão
ax1.set_xlabel('Tempo (s/RC)', color='white')
ax1.set_ylabel('Tensão no Capacitor $V_C(t)$ (V)', color='cyan')
ax1.plot(t/RC, Vc, label='Tensão no Capacitor $V_C(t)$', color='cyan')
ax1.tick_params(axis='x', colors='white')
ax1.tick_params(axis='y', labelcolor='cyan')

# Eixo da direita: carga
ax2 = ax1.twinx()
ax2.set_ylabel('Carga no Capacitor $Q(t)$ (μC)', color='magenta')
ax2.plot(t/RC, Q_micro, label='Carga $Q(t)$', color='magenta')
ax2.tick_params(axis='y', labelcolor='magenta')

# Título e grid
fig.suptitle('Carga do Capacitor: Tensão vs Carga', color='white')
ax1.grid(True, linestyle='--', alpha=0.3)

# Legenda
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='lower right')

plt.tight_layout()
plt.show()
# Out:
# [   0.           99.7000673   198.40612426  296.12808117  392.8757495
#   488.65884294  583.48697829  677.36967649  770.31636355  862.33637153
#   953.4389394  1043.63321406 1132.92825119 1221.3330162  1308.85638511
#  1395.50714544 1481.29399711 1566.22555329 1650.31034128 1733.55680338
#  1815.97329768 1897.56809898 1978.34939956 2058.32531004 2137.50386014
#  2215.89299957 2293.50059875 2370.33444965 2446.40226654 2521.71168677
#  2596.27027159 2670.08550681 2743.16480363 2815.51549938 2887.1448582
#  2958.06007184 3028.26826031 3097.77647268 3166.5916877  3234.72081456
#  3302.17069357 3368.94809683 3435.05972893 3500.51222762 3565.31216445
#  3629.46604548 3692.98031188 3755.86134062 3818.11544507 3879.74887569
#  3940.76782059 4001.1784062  4060.98669786 4120.19870045 4178.82035898
#  4236.85755918 4294.3161281  4351.2018347  4407.52039043 4463.27744977
#  4518.47861086 4573.129416   4627.23535225 4680.80185194 4733.83429328
#  4786.33800082 4838.31824604 4889.78024786 4940.72917318 4991.17013738
#  5041.10820482 5090.54838939 5139.49565499 5187.95491602 5235.93103789
#  5283.4288375  5330.45308374 5377.00849792 5423.09975431 5468.73148056
#  5513.90825819 5558.63462305 5602.91506575 5646.75403214 5690.15592373
#  5733.12509818 5775.66586967 5817.78250938 5859.47924591 5900.76026569
#  5941.62971343 5982.0916925  6022.15026537 6061.80945399 6101.07324024
#  6139.94556627 6178.43033496 6216.53141024 6254.25261754 6291.59774415
#  6328.5705396  6365.17471603 6401.41394857 6437.29187572 6472.8120997
#  6507.97818681 6542.79366778 6577.26203818 6611.3867587  6645.17125552
#  6678.61892068 6711.73311239 6744.51715539 6776.97434126 6809.10792877
#  6840.9211442  6872.41718165 6903.5992034  6934.47034018 6965.03369152
#  6995.29232604 7025.24928177 7054.90756645 7084.27015784 7113.34000399
#  7142.12002357 7170.61310617 7198.82211255 7226.74987494 7254.39919735
#  7281.77285583 7308.87359875 7335.70414708 7362.26719466 7388.56540849
#  7414.60142894 7440.37787009 7465.89731995 7491.16234073 7516.17546908
#  7540.93921636 7565.45606893 7589.7284883  7613.7589115  7637.54975121
#  7661.10339609 7684.42221097 7707.50853711 7730.36469243 7752.99297172
#  7775.39564691 7797.57496728 7819.53315968 7841.27242875 7862.79495717
#  7884.10290583 7905.1984141  7926.08360001 7946.76056047 7967.2313715
#  7987.49808841 8007.56274601 8027.42735884 8047.09392135 8066.5644081
#  8085.84077396 8104.92495433 8123.81886529 8142.52440383 8161.04344802
#  8179.37785722 8197.52947224 8215.50011553 8233.29159139 8250.90568611
#  8268.34416819 8285.60878849 8302.70128041 8319.62336007 8336.37672647
#  8352.96306171 8369.38403107 8385.64128325 8401.73645052 8417.67114887
#  8433.44697816 8449.06552233 8464.52834951 8479.8370122  8494.99304742
#  8509.99797687 8524.85330707 8539.56052952 8554.12112087 8568.53654303
#  8582.80824333 8596.93765468 8610.9261957  8624.77527088 8638.48627069
#  8652.06057173 8665.4995369  8678.8045155  8691.97684337 8705.01784305
#  8717.92882387 8730.71108212 8743.36590118 8755.8945516  8768.29829129
#  8780.57836562 8792.73600752 8804.77243765 8816.68886449 8828.48648447
#  8840.16648211 8851.73003009 8863.17828942 8874.51240952 8885.73352837
#  8896.84277259 8907.84125758 8918.73008759 8929.51035589 8940.18314485
#  8950.74952603 8961.21056031 8971.56729802 8981.82077898 8991.97203266
#  9002.02207828 9011.97192488 9021.82257144 9031.57500698 9041.23021068
#  9050.78915193 9060.25279048 9069.62207648 9078.89795064 9088.08134427
#  9097.1731794  9106.17436888 9115.08581644 9123.90841681 9132.64305579
#  9141.29061036 9149.85194875 9158.32793054 9166.71940674 9175.02721986
#  9183.25220403 9191.39518506 9199.4569805  9207.4383998  9215.34024428
#  9223.16330733 9230.90837438 9238.57622307 9246.16762325 9253.68333712
#  9261.12411927 9268.49071677 9275.78386925 9283.00430895 9290.15276081
#  9297.22994256 9304.23656477 9311.1733309  9318.04093742 9324.84007387
#  9331.57142288 9338.23566029 9344.83345521 9351.36547007 9357.8323607
#  9364.23477638 9370.57335994 9376.84874778 9383.06156996 9389.21245026
#  9395.30200624 9401.33084931 9407.29958477 9413.2088119  9419.05912399
#  9424.85110843 9430.58534675 9436.26241468 9441.8828822  9447.44731362
#  9452.95626762 9458.41029732 9463.8099503  9469.1557687  9474.44828926
#  9479.68804335 9484.87555706 9490.01135122 9495.09594148 9500.12983835
#  9505.11354722 9510.04756849 9514.93239753 9519.76852479 9524.55643583
#  9529.29661136 9533.98952731 9538.63565486 9543.23546049 9547.78940602
#  9552.29794869 9556.76154115 9561.18063157 9565.55566363 9569.88707658
#  9574.17530533 9578.4207804  9582.62392805 9586.7851703  9590.90492493
#  9594.98360558 9599.02162176 9603.01937889 9606.97727836 9610.89571754
#  9614.77508985 9618.6157848  9622.41818799 9626.1826812  9629.90964238
#  9633.59944574 9637.25246173 9640.86905713 9644.44959504 9647.99443498
#  9651.50393283 9654.97844096 9658.41830823 9661.82387999 9665.19549819
#  9668.53350132 9671.83822455 9675.10999966 9678.34915515 9681.55601623
#  9684.73090489 9687.87413989 9690.98603682 9694.06690811 9697.1170631
#  9700.13680802 9703.12644606 9706.08627739 9709.01659918 9711.91770565
#  9714.78988806 9717.6334348  9720.44863135 9723.23576038 9725.99510171
#  9728.72693239 9731.4315267  9734.10915619 9736.76008969 9739.38459337
#  9741.98293072 9744.55536264 9747.10214739 9749.62354069 9752.11979567
#  9754.59116298 9757.03789073 9759.4602246  9761.85840778 9764.23268106
#  9766.58328281 9768.91044905 9771.21441343 9773.49540727 9775.75365958
#  9777.98939711 9780.20284431 9782.39422343 9784.56375449 9786.71165531
#  9788.83814154 9790.94342669 9793.02772213 9795.09123714 9797.13417888
#  9799.15675248 9801.15916101 9803.14160551 9805.10428503 9807.04739662
#  9808.97113538 9810.87569444 9812.76126504 9814.62803649 9816.47619621
#  9818.30592977 9820.11742087 9821.9108514  9823.68640141 9825.44424917
#  9827.18457118 9828.90754217 9830.61333513 9832.30212132 9833.9740703
#  9835.62934993 9837.26812642 9838.8905643  9840.49682645 9842.08707417
#  9843.6614671  9845.22016333 9846.76331934 9848.29109008 9849.80362893
#  9851.30108776 9852.78361692 9854.25136525 9855.70448012 9857.14310742
#  9858.5673916  9859.97747566 9861.37350117 9862.75560829 9864.1239358
#  9865.47862108 9866.81980013 9868.14760762 9869.46217686 9870.76363983
#  9872.05212721 9873.32776837 9874.59069137 9875.84102302 9877.07888886
#  9878.30441316 9879.51771898 9880.71892813 9881.90816122 9883.08553765
#  9884.25117563 9885.40519219 9886.54770319 9887.67882335 9888.79866624
#  9889.90734429 9891.0049688  9892.09165    9893.16749698 9894.23261775
#  9895.28711926 9896.33110739 9897.36468694 9898.38796171 9899.40103441
#  9900.40400678 9901.3969795  9902.38005228 9903.35332381 9904.31689182
#  9905.27085306 9906.21530329 9907.15033735 9908.07604911 9908.99253152
#  9909.89987659 9910.79817543 9911.68751822 9912.56799426 9913.43969194
#  9914.3026988  9915.15710147 9916.00298574 9916.84043653 9917.66953794
#  9918.4903732  9919.30302473 9920.10757412 9920.90410214 9921.69268877
#  9922.47341319 9923.24635379 9924.01158815 9924.76919313 9925.51924478
#  9926.26181841 9926.99698858 9927.7248291  9928.44541304 9929.15881275
#  9929.86509986 9930.56434529 9931.25661923 9931.9419912  9932.62053001]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
plt.style.use('classic')

# --- Dados experimentais ---
time = np.array([0, 30, 60, 90, 120, 150, 180, 210, 240, 270,
                 300, 330, 360, 390, 420, 450, 480, 510, 570, 600])
capacitor = np.array([0.5, 1.9, 2.61, 3.25, 3.84, 4.33, 4.7, 5.10, 5.44, 5.71,
                      6.01, 6.23, 6.23, 6.47, 6.70, 7.08, 7.22, 7.35, 7.67, 7.75])

# --- Constante R ---
R = 147900  # em ohms

# --- Função teórica de carga do capacitor ---
def carga_capacitor(t, C, E):
    return E * (1 - np.exp(-t / (R * C)))

# --- Chute inicial ---
p0 = [1e-4, 10]  # C em farads, E em volts

# --- Ajuste ---
params, _ = curve_fit(carga_capacitor, time, capacitor, p0=p0)
C_fit, E_fit = params
tau_fit = R * C_fit  # constante de tempo ajustada

# --- Valores para plot ---
t_fit = np.linspace(0, 600, 500)
vc_fit = carga_capacitor(t_fit, C_fit, E_fit)

# --- Plot ---
plt.figure(figsize=(5, 6), facecolor='black',dpi=600)
ax = plt.gca()
ax.set_facecolor('black')

plt.plot(time, capacitor, 'o', color='lime', label='Dados experimentais')

# --- Colocar equação no gráfico ---
equacao_ = r'$V_C(t) = \epsilon_0 (1 - e^{{-t/(RC)}})$'


equacao = f'$V_C(t) = {E_fit:.2f} (1 - e^{{-t/({tau_fit:.2f})}})$'

plt.xlabel(r'$Tempo\ (s)$', color='white', fontsize=14)
plt.ylabel(r'$V_C(t)\ (V)$', color='white', fontsize=14)
plt.title('Carga do Capacitor\n'+r'$R = 147.9K\Omega$'+' | '+r'$\epsilon=10V$', color='white')
plt.grid(True, linestyle='--', alpha=0.3,color='white')
plt.tick_params(colors='white')

# Legenda personalizada
legend = ax.legend(loc='lower right')
legend.get_frame().set_facecolor('black')
legend.get_frame().set_edgecolor('white')
legend_texts = legend.get_texts()
legend_texts[0].set_color('lime')


plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
plt.style.use('classic')

# --- Dados experimentais ---
time = np.array([0, 30, 60, 90, 120, 150, 180, 210, 240, 270,
                 300, 330, 360, 390, 420, 450, 480, 510, 570, 600])
capacitor = np.array([0.5, 1.9, 2.61, 3.25, 3.84, 4.33, 4.7, 5.10, 5.44, 5.71,
                      6.01, 6.23, 6.23, 6.47, 6.70, 7.08, 7.22, 7.35, 7.67, 7.75])

# --- Constante R ---
R = 147900  # em ohms

# --- Função teórica de carga do capacitor ---
def carga_capacitor(t, C, E):
    return E * (1 - np.exp(-t / (R * C)))

# --- Chute inicial ---
p0 = [1e-4, 10]  # C em farads, E em volts

# --- Ajuste ---
params, _ = curve_fit(carga_capacitor, time, capacitor, p0=p0)
C_fit, E_fit = params
tau_fit = R * C_fit  # constante de tempo ajustada

# --- Valores para plot ---
t_fit = np.linspace(0, 600, 500)
vc_fit = carga_capacitor(t_fit, C_fit, E_fit)

# --- Plot ---
plt.figure(figsize=(5, 6), facecolor='black',dpi=600)
ax = plt.gca()
ax.set_facecolor('black')

plt.plot(time, capacitor, 'o', color='lime', label='Dados experimentais')
plt.plot(t_fit, vc_fit, '--', color='cyan', label=f'Ajuste teórico\n'+fr'$C = {C_fit:.2e} F$'+'\n'+fr'$\epsilon_0 = {E_fit:.2f} V$'+'\n'+fr'$RC = {tau_fit:.2f} s$')
# --- Colocar equação no gráfico ---
equacao_ = r'$V_C(t) = \epsilon_0 (1 - e^{{-t/(RC)}})$'
plt.text(0, max(capacitor)*.97, equacao_, color='gold', fontsize=17, bbox=dict(facecolor='black', alpha=0.5))


equacao = f'$V_C(t) = {E_fit:.2f} (1 - e^{{-t/({tau_fit:.2f})}})$'
plt.text(180, max(capacitor)*0.5, equacao, color='cyan', fontsize=18, bbox=dict(facecolor='black', alpha=0.5))

plt.xlabel(r'$Tempo\ (s)$', color='white', fontsize=14)
plt.ylabel(r'$V_C(t)\ (V)$', color='white', fontsize=14)
plt.title('Ajuste da Curva de Carga do Capacitor\n'+r'$R = 147.9K\Omega$'+' | '+r'$\epsilon=10V$', color='white')
plt.grid(True, linestyle='--', alpha=0.3,color='white')
plt.tick_params(colors='white')

# Legenda personalizada
legend = ax.legend(loc='lower right')
legend.get_frame().set_facecolor('black')
legend.get_frame().set_edgecolor('gold')
legend_texts = legend.get_texts()
legend_texts[0].set_color('lime')
legend_texts[1].set_color('cyan')

plt.tight_layout()
plt.show()

# %%
## resistor

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
plt.style.use('classic')

# Dados
resistor = np.array([10, 8.13, 7.35, 6.76, 6.16, 5.69, 5.27, 4.89, 4.55, 4.30,
                     4.02, 3.75, 3.54, 3.28, 3.02, 2.91, 2.76, 2.62, 2.32, 2.24])
time = np.array([0, 30, 60, 90, 120, 150, 180, 210, 240, 270,
                 300, 330, 360, 390, 420, 450, 480, 510, 570, 600])
# Função exponencial teórica
def exp_func(t, a, b, c):
    return a * np.exp(-b * t) + c

# Ajuste dos parâmetros
params, _ = curve_fit(exp_func, time, resistor, p0=(10, 0.1, 2))
a, b, c = params

# Gráfico
plt.figure(figsize=(5, 6), facecolor='black')
ax = plt.gca()
ax.set_facecolor('black')

plt.title("Variação da Potência no Resistor\nno Carregamento", color='white', fontsize=12, pad=15)
plt.ylabel(r'V', color='white')
plt.xlabel('Tempo (s)', color='white')

plt.grid(True, linestyle='--', alpha=0.4,color='white')
plt.tick_params(colors='white')

# Dados experimentais
plt.plot(time, resistor, 'o', color='cyan', label='Dados experimentais')

# Ajuste teórico
t_fit = np.linspace(0, len(resistor)-1, 200)

# Equação ajustada (formatada)
equation_text = fr"$R(t) = {a:.2f} \, e^{{-{b:.2f}t}} + {c:.2f}$"

# Legenda
legend = plt.legend(facecolor='black', edgecolor='white', fontsize=9)
for text in legend.get_texts():
    text.set_color("white")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from statistics import stdev,mean
plt.style.use('classic')

# Dados
resistor = np.array([10, 8.13, 7.35, 6.76, 6.16, 5.69, 5.27, 4.89, 4.55, 4.30,
                     4.02, 3.75, 3.54, 3.28, 3.02, 2.91, 2.76, 2.62, 2.32, 2.24])
capacitor = np.array([0.5, 2.9, 2.61, 3.25, 3.84, 4.33, 4.7, 5.10, 5.44, 5.71,
                      6.01, 6.23, 6.23, 6.47, 6.70, 7.08, 7.22, 7.35, 7.67, 7.75])
rc_ = capacitor + resistor
m_rc = mean(rc_)
desv = stdev(rc_)
m_rc_desv_minus = m_rc-desv
m_rc_desv_plus = m_rc+desv
print(rc_)
print('média:',m_rc,'\t','desvio:',desv)
m_rc_minus_ = np.ones(len(rc_)+2)*m_rc_desv_minus
m_rc_plus_ = np.ones(len(rc_)+2)*m_rc_desv_plus
time = np.linspace(0,600,len(resistor))
time_ = np.linspace(-30,630,len(resistor)+2)

# Função exponencial teórica
def exp_func(t, a, b, c):
    return a * np.exp(-b * t) + c


# Gráfico
plt.figure(figsize=(5, 6), facecolor='black')
ax = plt.gca()
ax.set_facecolor('black')

plt.title("Soma da Variação da Potência no Resistor e no Capacitor\nno Carregamento", color='white', fontsize=12, pad=15)
plt.ylabel(r'V', color='white')
plt.xlabel('Tempo (s)', color='white')
plt.ylim([9,11])
plt.grid(True, linestyle='--', alpha=0.4,color='white')
plt.tick_params(colors='white')

# Dados experimentais
plt.plot(time, rc_, 'o', color='cyan', label='Dados experimentais')
plt.plot(time_,m_rc*np.ones(len(time_)),'o-',c='green',label=f'média: {m_rc:.2f}')
plt.plot(time_,m_rc_minus_,'--',c='yellow',label='desvio padrão: 'f'{m_rc:.2f}'+r'$\mp$'+f'{desv:.2f}')
plt.plot(time_,m_rc_plus_,'--',c='yellow')
# Ajuste teórico


# Legenda
legend = plt.legend(facecolor='black', edgecolor='white', fontsize=9)
for text in legend.get_texts():
    text.set_color("white")

plt.show()
# Out:
# [10.5  11.03  9.96 10.01 10.   10.02  9.97  9.99  9.99 10.01 10.03  9.98
#   9.77  9.75  9.72  9.99  9.98  9.97  9.99  9.99]
# média: 10.0325 	 desvio: 0.2800164468853855

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean, stdev

# --- Dados ---
resistor = np.array([10, 8.13, 7.35, 6.76, 6.16, 5.69, 5.27, 4.89, 4.55, 4.30,
                     4.02, 3.75, 3.54, 3.28, 3.02, 2.91, 2.76, 2.62, 2.32, 2.24])
capacitor = np.array([0.5, 2.9, 2.61, 3.25, 3.84, 4.33, 4.7, 5.10, 5.44, 5.71,
                      6.01, 6.23, 6.23, 6.47, 6.70, 7.08, 7.22, 7.35, 7.67, 7.75])
# --- Cálculo média e desvio ---
rc_ = capacitor + resistor
m_rc = mean(rc_)
desv = stdev(rc_)
print(rc_)
print('Média:', m_rc, '\tDesvio:', desv)

# --- Preparar linhas de média ± desvio ---
m_rc_desv_minus = m_rc - desv
m_rc_desv_plus = m_rc + desv
m_rc_minus_ = np.ones(len(rc_)) * m_rc_desv_minus
m_rc_plus_ = np.ones(len(rc_)) * m_rc_desv_plus

# --- Tempo para o eixo x ---
time = np.linspace(0, 600, len(resistor))

# --- Plotagem ---
plt.figure(figsize=(10,6))
plt.plot(time, rc_, 'o-', label='R + C', color='blue')
plt.plot(time, np.ones(len(time))*m_rc, '--', color='red', label=f'Média ({m_rc:.2f})')
plt.plot(time, m_rc_minus_, '--', color='green', label=f'Média - 1σ ({m_rc_desv_minus:.2f})')
plt.plot(time, m_rc_plus_, '--', color='green', label=f'Média + 1σ ({m_rc_desv_plus:.2f})')

plt.xlabel('Tempo (s)')
plt.ylabel('Resistor + Capacitor')
plt.title('Soma de R e C com Média e Desvio Padrão')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [10.5  11.03  9.96 10.01 10.   10.02  9.97  9.99  9.99 10.01 10.03  9.98
#   9.77  9.75  9.72  9.99  9.98  9.97  9.99  9.99]
# Média: 10.0325 	Desvio: 0.2800164468853855

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

# --- Dados ---
resistor = np.array([10, 8.13, 7.35, 6.76, 6.16, 5.69, 5.27, 4.89, 4.55, 4.30,
                     4.02, 3.75, 3.54, 3.28, 3.02, 2.91, 2.76, 2.62, 2.32, 2.24])
capacitor = np.array([0.5, 2.9, 2.61, 3.25, 3.84, 4.33, 4.7, 5.10, 5.44, 5.71,
                      6.01, 6.23, 6.23, 6.47, 6.70, 7.08, 7.22, 7.35, 7.67, 7.75])
# --- Soma R + C ---
rc_ = resistor + capacitor
m_rc = mean(rc_)

# --- Erro individual: diferença absoluta entre cada ponto e a média ---
erro = np.abs(rc_ - m_rc)

# --- Tempo ---
time = np.linspace(0, 600, len(rc_))

# --- Plotagem com barras de erro ---
plt.figure(figsize=(10,6))
plt.errorbar(time, rc_, yerr=erro, fmt='o', ecolor='purple', capsize=5, label='R + C com "confiança"')
plt.axhline(m_rc, color='red', linestyle='--', label=f'Média ({m_rc:.2f})')

plt.plot(time, m_rc_minus_, '--', color='green', label=f'Média - 1σ ({m_rc_desv_minus:.2f})')
plt.plot(time, m_rc_plus_, '--', color='green', label=f'Média + 1σ ({m_rc_desv_plus:.2f})')


plt.xlabel('Tempo (s)')
plt.ylabel('Resistor + Capacitor')
plt.title('Soma de R e C com Barras de Erro (Diferença para a Média)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean
plt.style.use('default')
# --- Dados ---
resistor = np.array([10, 8.13, 7.35, 6.76, 6.16, 5.69, 5.27, 4.89, 4.55, 4.30,
                     4.02, 3.75, 3.54, 3.28, 3.02, 2.91, 2.76, 2.62, 2.32, 2.24])
capacitor = np.array([0.5, 1.9, 2.61, 3.25, 3.84, 4.33, 4.7, 5.10, 5.44, 5.71,
                      6.01, 6.23, 6.23, 6.47, 6.70, 7.08, 7.22, 7.35, 7.67, 7.75])

# --- Soma R + C ---
rc_ = resistor + capacitor
m_rc = mean(rc_)

# --- Erro individual: diferença absoluta entre cada ponto e a média ---
erro = np.abs(rc_ - m_rc)

# --- Tempo ---
time = np.linspace(0, 600, len(rc_))

# --- Plotagem com barras de erro ---
plt.figure(figsize=(6,6),dpi=600)
plt.errorbar(time, rc_, yerr=erro, fmt='o', ecolor='purple', capsize=5, label='R + C com "confiança"')
plt.axhline(m_rc, color='red', linestyle='--', label=f'Média ({m_rc:.2f})')

# --- Anotar discrepância em cada ponto ---
for t, val, e in zip(time, rc_, rc_ - m_rc):
    plt.text(t, val + 0.1, f'{e:+.2f}', ha='center', va='bottom', fontsize=8, color='blue')

plt.xlabel('Tempo (s)')
plt.ylabel('Resistor + Capacitor')
plt.title('Soma de R e C com Barras de Erro e Discrepância de Cada Ponto')
plt.legend()
plt.grid(True)

plt.show()
